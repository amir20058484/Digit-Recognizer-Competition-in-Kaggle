# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.callbacks import EarlyStopping

# %%
train = pd.read_csv('/kaggle/input/digit-recognizer/train.csv')
test = pd.read_csv('/kaggle/input/digit-recognizer/test.csv')

X_train = train.drop('label', axis=1).values
y_train = train['label'].values
X_test = test.values

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
y_train = to_categorical(y_train, 10)

# %%
model = Sequential([
    Input(shape=(784,)),

    Dense(256, activation='relu', kernel_initializer=HeNormal()),
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, activation='relu', kernel_initializer=HeNormal()),
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, activation='relu', kernel_initializer=HeNormal()),
    BatchNormalization(),
    Dropout(0.2),

    Dense(32, activation='relu', kernel_initializer=HeNormal()),
    BatchNormalization(),
    Dropout(0.2),

    Dense(10, activation='softmax')
])

# %%
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', 
                           patience=3,        
                           restore_best_weights=True)

model.fit(X_train, y_train,
          epochs=50,
          batch_size=32,
          validation_split=0.2, 
          callbacks=[early_stop])
# Out:
# Epoch 1/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6980 - loss: 0.9641 - val_accuracy: 0.9437 - val_loss: 0.1806
# Epoch 2/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9131 - loss: 0.3056 - val_accuracy: 0.9595 - val_loss: 0.1357
# Epoch 3/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9286 - loss: 0.2388 - val_accuracy: 0.9635 - val_loss: 0.1217
# Epoch 4/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9365 - loss: 0.2195 - val_accuracy: 0.9657 - val_loss: 0.1112
# Epoch 5/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9476 - loss: 0.1797 - val_accuracy: 0.9700 - val_loss: 0.0977
# Epoch 6/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9540 - loss: 0.1562 - val_accuracy: 0.9717 - val_loss: 0.0997
# Epoch 7/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9572 - loss: 0.1510 - val_accuracy: 0.9710 - val_loss: 0.1005
# Epoch 8/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9592 - loss: 0.1413 - val_accuracy: 0.9735 - val_loss: 0.0940
# Epoch 9/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9612 - loss: 0.1359 - val_accuracy: 0.9735 - val_loss: 0.0933
# Epoch 10/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9656 - loss: 0.1180 - val_accuracy: 0.9736 - val_loss: 0.0928
# Epoch 11/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9674 - loss: 0.1111 - val_accuracy: 0.9757 - val_loss: 0.0842
# Epoch 12/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9684 - loss: 0.1057 - val_accuracy: 0.9754 - val_loss: 0.0888
# Epoch 13/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9698 - loss: 0.0974 - val_accuracy: 0.9777 - val_loss: 0.0818
# Epoch 14/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9701 - loss: 0.0973 - val_accuracy: 0.9758 - val_loss: 0.0857
# Epoch 15/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9730 - loss: 0.0937 - val_accuracy: 0.9790 - val_loss: 0.0764
# Epoch 16/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9721 - loss: 0.0912 - val_accuracy: 0.9779 - val_loss: 0.0773
# Epoch 17/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9745 - loss: 0.0824 - val_accuracy: 0.9789 - val_loss: 0.0759
# Epoch 18/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9747 - loss: 0.0840 - val_accuracy: 0.9801 - val_loss: 0.0783
# Epoch 19/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9771 - loss: 0.0757 - val_accuracy: 0.9762 - val_loss: 0.0894
# Epoch 20/50
# 1050/1050 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9774 - loss: 0.0800 - val_accuracy: 0.9760 - val_loss: 0.0849

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
# Out:
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
submission = pd.DataFrame({'ImageId': np.arange(1, len(y_pred) + 1), 'Label': y_pred})
submission.to_csv('/kaggle/working/submission.csv', index=False)

submission.head()
# Out:
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      0
# 4        5      3
